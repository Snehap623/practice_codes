# %%
import pandas as pd

# %%
df=pd.read_csv ('/machine-readable-business-employment-data-dec-2024-quarter.csv')

# %%
df.values
# Out:
# array([['BDCQ.SEA1AA', 2011.06, 80078.0, ..., 'Actual', nan, nan],
#        ['BDCQ.SEA1AA', 2011.09, 78324.0, ..., 'Actual', nan, nan],
#        ['BDCQ.SEA1AA', 2011.12, 85850.0, ..., 'Actual', nan, nan],
#        ...,
#        ['BDCQ.SEE3999A', 2017.12, nan, ..., 'Actual', nan, nan],
#        ['BDCQ.SEE3999A', 2018.03, nan, ..., 'Actual', nan, nan],
#        ['BDCQ.SEE3999A', 2018.06, nan, ..., 'Actual', nan, nan]],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=24124, step=1),
#  Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#         'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#         'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4      float64
# Series_title_5      float64
# dtype: object

# %%
df.shape
# Out:
# (24124, 14)

# %%
df.size
# Out:
# 337736

# %%
df.ndim
# Out:
# 2

# %%
df.head(50)
# Out:
#    Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0       BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1       BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2       BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3       BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4       BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
# 5       BDCQ.SEA1AA  2012.09     79261.0        NaN      F  Number          0
# 6       BDCQ.SEA1AA  2012.12     87793.0        NaN      F  Number          0
# 7       BDCQ.SEA1AA  2013.03     91571.0        NaN      F  Number          0
# 8       BDCQ.SEA1AA  2013.06     81687.0        NaN      F  Number          0
# 9       BDCQ.SEA1AA  2013.09     81471.0        NaN      F  Number          0
# 10      BDCQ.SEA1AA  2013.12     93950.0        NaN      F  Number          0
# ...

# %%
df.describe()
# Out:
#              Period    Data_value     Magnitude  Series_title_4  \
# count  24124.000000  2.128500e+04  24124.000000             0.0
# mean    2017.456557  7.325791e+04      2.285442             NaN
# std        3.905518  2.120331e+05      2.913719             NaN
# min     2011.060000  1.187001e+00      0.000000             NaN
# 25%     2014.090000  1.906000e+03      0.000000             NaN
# 50%     2017.120000  1.416800e+04      0.000000             NaN
# 75%     2021.030000  6.080000e+04      6.000000             NaN
# max     2024.120000  2.321295e+06      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
df.Magnitude.describe()
# Out:
# count    24124.000000
# mean         2.285442
# std          2.913719
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          6.000000
# max          6.000000
# Name: Magnitude, dtype: float64

# %%
df.sample(10)
# Out:
#       Series_reference   Period    Data_value Suppressed STATUS   UNITS  \
# 3694       BDCQ.SEA2CT  2019.12           NaN          Y      C   Value
# 14542    BDCQ.SEE1036A  2016.03   5058.000000        NaN      F  Number
# 1598       BDCQ.SEA1JT  2012.03  35997.000000        NaN      R  Number
# 18429    BDCQ.SEE2040A  2011.06    378.079931        NaN      F   Value
# 23582    BDCQ.SEE3067A  2020.09    320.000000        NaN      F  Number
# 149        BDCQ.SEA1AT  2021.03  97537.000000        NaN      R  Number
# 11426     BDCQ.SED2RKS  2014.03           NaN          Y      R   Value
# 10417     BDCQ.SED2RCT  2018.03           NaN          Y      C   Value
# 11072     BDCQ.SED2RHT  2015.09           NaN          Y      C   Value
# 5316       BDCQ.SEA2PA  2016.09   2531.298084        NaN      F   Value
#
#        Magnitude                         Subject  \
# 3694           6  Business Data Collection - BDC
# 14542          0  Business Data Collection - BDC
# ...

# %%
df.Magnitude.sample(10)
# Out:
# 1587     0
# 4459     6
# 10462    6
# 8258     0
# 6375     0
# 12381    0
# 461      0
# 13433    0
# 1785     0
# 22994    0
# Name: Magnitude, dtype: int64

# %%
df.groupby ('Group')[['Period']].mean()
# Out:
#                                                    Period
# Group
# Age by employment variable                    2017.694000
# Industry by employment variable               2017.169866
# Region by employment variable                 2017.251530
# Sex by employment variable                    2017.694000
# Territorial authority by employment variable  2017.684513

# %%
df_sub= df[df['Period']==2016]

# %%
df_sub.values
# Out:
# array([], shape=(0, 14), dtype=object)

# %%
df_sub.head(10)
# Out:
# Empty DataFrame
# Columns: [Series_reference, Period, Data_value, Suppressed, STATUS, UNITS, Magnitude, Subject, Group, Series_title_1, Series_title_2, Series_title_3, Series_title_4, Series_title_5]
# Index: []

# %%
df.iloc[:,0:2]
# Out:
#       Series_reference   Period
# 0          BDCQ.SEA1AA  2011.06
# 1          BDCQ.SEA1AA  2011.09
# 2          BDCQ.SEA1AA  2011.12
# 3          BDCQ.SEA1AA  2012.03
# 4          BDCQ.SEA1AA  2012.06
# ...                ...      ...
# 24119    BDCQ.SEE3999A  2017.06
# 24120    BDCQ.SEE3999A  2017.09
# 24121    BDCQ.SEE3999A  2017.12
# 24122    BDCQ.SEE3999A  2018.03
# 24123    BDCQ.SEE3999A  2018.06
#
# [24124 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=(1,2,3)

# %%
y=(5,8,4)

# %%
f=plt.figure(figsize=(10,3))

# %%
plt.plot(x,y)

# %%
plt.xlim(4.5,10)
# Out:
# (4.5, 10.0)

# %%
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %%
plt.xlabel ('x axis')
# Out:
# Text(0.5, 0, 'x axis')

# %%
plt.ylabel('yaxis')
# Out:
# Text(0, 0.5, 'yaxis')

# %%
plt.hist(df['Magnitude'])
# Out:
# (array([14935.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#             0.,  9189.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Period'],vert=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc28b941e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc28b8ca710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc28be361d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc28b8cbdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc28b8c8750>],
#  'means': []}
